# %%
import socrata_glossarizer

# %%
socrata_glossarizer.write_resource_representation(endpoint_type='link')
# Out:
# 100%|██████████| 182/182 [03:56<00:00,  1.28s/it]

# %%
socrata_glossarizer.write_dataset_representation(endpoint_type='link', timeout=60)
# Out:
#  40%|████      | 73/182 [00:57<01:54,  1.05s/it]Process Process-74:
# Traceback (most recent call last):
#   File "/home/alex/miniconda3/envs/urban-physiology/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py", line 391, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/alex/miniconda3/envs/urban-physiology/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py", line 387, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/alex/miniconda3/envs/urban-physiology/lib/python3.5/http/client.py", line 1198, in getresponse
#     response.begin()
#   File "/home/alex/miniconda3/envs/urban-physiology/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/alex/miniconda3/envs/urban-physiology/lib/python3.5/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
# ...

# %%
socrata_glossarizer.write_glossary(endpoint_type='link', timeout=60)
# Out:
# > /home/alex/Desktop/urban-physiology/src/glossarizers/socrata-glossarizer/socrata_glossarizer.py(243)write_glossary()
# -> import sys; sys.path.insert(0, "../../limited-requests")
# (Pdb) from ..src import datafy
# *** SystemError: Parent module '' not loaded, cannot perform relative import
# (Pdb) from src import datafy
# *** ImportError: No module named 'src'
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-2-192cbe8afd71> in <module>()
# ----> 1 socrata_glossarizer.write_glossary(endpoint_type='link', timeout=60)
#
# /home/alex/Desktop/urban-physiology/src/glossarizers/socrata-glossarizer/socrata_glossarizer.py in write_glossary(domain, folder_slug, use_cache, endpoint_type, timeout)
#     241             # Import the necessary library.
#     242             import pdb; pdb.set_trace()
# ...
